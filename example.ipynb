# %% [markdown]
# <a href="https://colab.research.google.com/github/jadechip/Talk2Task/blob/main/example.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip -q install openai

# %%
import re
import os
import subprocess
import openai

# %%
class Tool:
    def __init__(self, name):
        self.name = name

    def useTool(self, command):
        pass

class CommandExecutor(Tool):
    def __init__(self):
        super().__init__('CommandExecutor')

    def useTool(self, command):
        result = subprocess.run(command, capture_output=True, shell=True)
        return result.stdout

class FileCreator(Tool):
    def __init__(self):
        super().__init__('FileCreator')

    def useTool(self, command):
        os.makedirs(command, exist_ok=True)
        return f"Directory {command} created."

class CodeWriter(Tool):
    def __init__(self, filename):
        super().__init__('CodeWriter')
        self.filename = filename

    def useTool(self, code):
        with open(self.filename, 'w') as file:
            file.write(code)
        return f"File {self.filename} written."

class Talk2Task:
    def __init__(self, api_key):
        self.api_key = api_key
        openai.api_key = api_key
        self.tool_map = {
            'CommandExecutor': CommandExecutor(),
            'FileCreator': FileCreator(),
        }
        self.tool_prompts = {
            'CommandExecutor': 'CommandExecutor allows you to run shell commands. Use it by writing [CommandExecutor(your_command)].',
            'FileCreator': 'FileCreator lets you create a directory. Use it by writing [FileCreator(/path/to/directory)].',
        }

    def generate_llm_messages(self, query):
        tool_descriptions = '\n'.join([f'{name}: {desc}' for name, desc in self.tool_prompts.items()])
        messages = [
            {
                "role": "system",
                "content": f"""
                Based on the tools available to you ({tool_descriptions}), break down a given task or query into specific steps. 
                For each step, specify the tool that should be used and the exact command that should be executed.
                Your response MUST be a JSON list of commands in the following format:
                [["ToolName", "Command1"], ["ToolName", "Command2"], ...]
                Do not provide any additional text or explanation in the response, only the JSON list of commands.
                Query:
                {query}
                """
            },
            {
                "role": "user",
                "content": query
            }
        ]
        return messages

    def interact_with_gpt(self, prompt):
        messages = self.generate_llm_messages(prompt)
        completion = openai.ChatCompletion.create(
            model="gpt-3.5-turbo",
            temperature=0.2,
            messages=messages
        )
        response = completion.choices[0].message['content']
        print(f"Response: {response}")

        return response

    def parse_response(self, response):
        response = self.preprocess_response(response)

        patterns = [
            r'\["(\w+)"\s*,\s*"([^"]+)"\]',
            r'\[(\w+)\((.+)\)\]',
        ]

        for pattern in patterns:
            matches = re.findall(pattern, response)
            if matches:
                break
        else:
            raise ValueError("Response does not contain a list of commands")

        commands = [(match[0], match[1]) for match in matches]

        return commands

    def preprocess_response(self, response):
        response = response.replace('\n', '')
        response = re.sub(r'\s+', ' ', response)
        return response.strip()

    def execute_commands(self, commands):
        results = []
        current_file = None
        for cmd in commands:
            tool, args = cmd
            if tool in self.tool_map:
                print(f"Executing command: {tool}({args})")
                result = self.tool_map[tool].useTool(args)
                print(f"Result: {result}\n")
                results.append((tool, args, result))
            else:
                raise Exception(f'Unknown command type: {tool}')
        return results

    def process_prompt(self, prompt, retry=3):
        try:
            response = self.interact_with_gpt(prompt)
            commands = self.parse_response(response)
            results = self.execute_commands(commands)
            return results
        except Exception as e:
            if retry > 0:
                print(f"Error encountered: {e}. Retrying...")
                return self.process_prompt(prompt, retry - 1)
            else:
                raise e

# %%
# Initialize the library with your OpenAI API key
lib = Talk2Task("<OPENAI_API_KEY>")

# Define a prompt that GPT-X will understand to create a directory
prompt = """
Create a phaser.js game called Turing Town with the following gameplay mechanics:

Starting a round: At the start of each round, the server should randomly assign roles to each connected player. These roles could be stored in memory or in a database, and each player's client should be notified of their role.

Example code:
roles = ['AI', 'Human']
players_roles = {player: random.choice(roles) for player in players}
Controlling avatars: Each player should have control over their avatar. For human players, this would involve sending movement and action commands from the client to the server. For AI players, the server should periodically send commands based on the AI's behavior.

Example code:
// Example of a human player sending a move command
socket.emit('move', { direction: 'up' });

// Example of the server moving an AI player
if (player.role === 'AI') {
  let action = AI.getAction(player);
  movePlayer(player, action);
}
Interactions and actions: The server needs to handle various interactions and actions, such as interacting with objects or communicating with other avatars. These could be handled as different types of commands sent from the client.

Example code:
// Example of a player interacting with an object
socket.emit('interact', { object: 'paintbrush' });
Decision making: Players should be able to vote on who they think is human. The server should handle these votes and keep track of them.

Example code:
// Example of a player voting
socket.emit('vote', { suspect: 'player2' });
Scoring: The server should calculate scores based on the rules you described. After each round, it should send the scores to each client.

Example code:
calculate_scores(players, votes)
AI learning: After each round, the AI should update its behavior based on the experiences of that round. This would involve integrating your AI models with the game server.
python
Copy code
for player in players:
  if player.role === 'AI':
    player.AI_model.update(experiences)
"""

# Process the prompt
result = lib.process_prompt(prompt)

# Print the result
print(result)
# Out:
# Response: [["CommandExecutor", "npm install phaser"],
# ["CommandExecutor", "npm install socket.io"],
# ["CommandExecutor", "npm install express"],
# ["FileCreator", "/path/to/TuringTown"],
# ["CommandExecutor", "cd /path/to/TuringTown && phaser init"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm init"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install nodemon"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install body-parser"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install cors"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install mongoose"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install dotenv"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install bcrypt"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install jsonwebtoken"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install axios"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow/tfjs"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/blazeface"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/posenet"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/mobilenet"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/handpose"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/face-landmarks-detection"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/face-landmarks-detection"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/face-embedding"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/knn-classifier"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/object-detection"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/pose-detection"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/speech-commands"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/universal-sentence-encoder"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/qna"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/transformer"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/gesture-estimation"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/human-pose-estimation"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/segmentation"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/visual-qa"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/visual-semantic-embedding"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/multihandpose"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/blazepose"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/efficientpose"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/facemesh"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/deeplab"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/transformer-xl"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/attention-ocr"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/visual-qa"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/visual-semantic-embedding"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/multihandpose"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/blazepose"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/efficientpose"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/facemesh"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/deeplab"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/transformer-xl"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/attention-ocr"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/visual-qa"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/visual-semantic-embedding"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/multihandpose"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/blazepose"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/efficientpose"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/facemesh"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/deeplab"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/transformer-xl"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/attention-ocr"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/visual-qa"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/visual-semantic-embedding"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/multihandpose"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/blazepose"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/efficientpose"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/facemesh"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/deeplab"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/transformer-xl"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/attention-ocr"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/visual-qa"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/visual-semantic-embedding"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/multihandpose"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/blazepose"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/efficientpose"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/facemesh"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/deeplab"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/transformer-xl"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/attention-ocr"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/visual-qa"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/visual-semantic-embedding"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/multihandpose"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/blazepose"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/efficientpose"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/facemesh"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/deeplab"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/transformer-xl"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/attention-ocr"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/visual-qa"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/visual-semantic-embedding"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/multihandpose"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/blazepose"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/efficientpose"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/facemesh"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/deeplab"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/transformer-xl"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/attention-ocr"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/visual-qa"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/visual-semantic-embedding"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/multihandpose"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/blazepose"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/efficientpose"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/facemesh"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/deeplab"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/transformer-xl"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/attention-ocr"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/visual-qa"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/visual-semantic-embedding"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/multihandpose"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/blazepose"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/efficientpose"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/facemesh"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/deeplab"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/transformer-xl"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/attention-ocr"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/visual-qa"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/visual-semantic-embedding"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/multihandpose"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/blazepose"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/efficientpose"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/facemesh"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/deeplab"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/transformer-xl"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/attention-ocr"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/visual-qa"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/visual-semantic-embedding"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/multihandpose"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/blazepose"],
# ["CommandExecutor", "cd /path/to/TuringTown && npm install @tensorflow-models/efficientpose"],
# ["CommandExecutor", "cd /path/to/Turing
# Executing command: CommandExecutor(npm install phaser)
# Result: b'+ phaser@3.60.0\nadded 2 packages from 2 contributors and audited 2 packages in 5.144s\nfound 0 vulnerabilities\n\n'
#
# Executing command: CommandExecutor(npm install socket.io)
# Result: b'+ socket.io@4.6.1\nadded 21 packages from 69 contributors and audited 23 packages in 2.736s\nfound 0 vulnerabilities\n\n'
#
# Executing command: CommandExecutor(npm install express)
# Result: b'+ express@4.18.2\nadded 58 packages from 39 contributors and audited 92 packages in 3.034s\n\n7 packages are looking for funding\n  run `npm fund` for details\n\nfound 0 vulnerabilities\n\n'
#
# Executing command: FileCreator(/path/to/TuringTown)
# Result: Directory /path/to/TuringTown created.
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && phaser init)
# Result: b''
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm init)
# Result: b'This utility will walk you through creating a package.json file.\nIt only covers the most common items, and tries to guess sensible defaults.\n\nSee `npm help init` for definitive documentation on these fields\nand exactly what they do.\n\nUse `npm install <pkg>` afterwards to install a package and\nsave it as a dependency in the package.json file.\n\nPress ^C at any time to quit.\npackage name: (turingtown) '
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install)
# Result: b'up to date in 0.292s\nfound 0 vulnerabilities\n\n'
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install nodemon)
# Result: b'+ nodemon@2.0.22\nadded 32 packages from 28 contributors and audited 33 packages in 2.099s\n\n3 packages are looking for funding\n  run `npm fund` for details\n\nfound 0 vulnerabilities\n\n'
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install body-parser)
# Result: b'+ body-parser@1.20.2\nadded 30 packages from 22 contributors and audited 82 packages in 1.644s\n\n9 packages are looking for funding\n  run `npm fund` for details\n\nfound 0 vulnerabilities\n\n'
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install cors)
# Result: b'+ cors@2.8.5\nadded 3 packages from 3 contributors and audited 112 packages in 0.867s\n\n9 packages are looking for funding\n  run `npm fund` for details\n\nfound 0 vulnerabilities\n\n'
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install mongoose)
# Result: b'+ mongoose@7.1.1\nadded 23 packages from 64 contributors and audited 137 packages in 3.355s\n\n10 packages are looking for funding\n  run `npm fund` for details\n\nfound 0 vulnerabilities\n\n'
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install dotenv)
# Result: b'+ dotenv@16.0.3\nadded 1 package and audited 150 packages in 1.065s\n\n10 packages are looking for funding\n  run `npm fund` for details\n\nfound 0 vulnerabilities\n\n'
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install bcrypt)
# Result: b'\n> bcrypt@5.1.0 install /path/to/TuringTown/node_modules/bcrypt\n> node-pre-gyp install --fallback-to-build\n\n[bcrypt] Success: "/path/to/TuringTown/node_modules/bcrypt/lib/binding/napi-v3/bcrypt_lib.node" is installed via remote\n+ bcrypt@5.1.0\nadded 55 packages from 134 contributors and audited 205 packages in 4.864s\n\n14 packages are looking for funding\n  run `npm fund` for details\n\nfound 0 vulnerabilities\n\n'
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install jsonwebtoken)
# Result: b'+ jsonwebtoken@9.0.0\nadded 7 packages from 8 contributors and audited 257 packages in 2.043s\n\n14 packages are looking for funding\n  run `npm fund` for details\n\nfound 0 vulnerabilities\n\n'
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install axios)
# Result: b'+ axios@1.4.0\nadded 7 packages from 21 contributors and audited 267 packages in 1.773s\n\n15 packages are looking for funding\n  run `npm fund` for details\n\nfound 0 vulnerabilities\n\n'
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow/tfjs)
# Result: b'\n> core-js@3.29.1 postinstall /path/to/TuringTown/node_modules/core-js\n> node -e "try{require(\'./postinstall\')}catch(e){}"\n\n\x1bThank you for using core-js (\x1b https://github.com/zloirock/core-js \x1b) for polyfilling JavaScript standard library!\x1b\n\n\x1bThe project needs your help! Please consider supporting of core-js:\x1b\n\x1b>\x1b https://opencollective.com/core-js \x1b\n\x1b>\x1b https://patreon.com/zloirock \x1b\n\x1b>\x1b https://boosty.to/zloirock \x1b\n\x1b>\x1b bitcoin: bc1qlea7544qtsmj2rayg0lthvza9fau63ux0fstcz \x1b\n\n\x1bI highly recommend reading this:\x1b https://github.com/zloirock/core-js/blob/master/docs/2023-02-14-so-whats-next.md \x1b\x1b\n\n+ @tensorflow/tfjs@4.5.0\nadded 35 packages from 36 contributors and audited 307 packages in 18.195s\n\n19 packages are looking for funding\n  run `npm fund` for details\n\nfound 0 vulnerabilities\n\n'
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/blazeface)
# Result: b'+ @tensorflow-models/blazeface@0.0.7\nadded 1 package and audited 340 packages in 5.67s\n\n19 packages are looking for funding\n  run `npm fund` for details\n\nfound 0 vulnerabilities\n\n'
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/posenet)
# Result: b'+ @tensorflow-models/posenet@2.2.2\nadded 1 package and audited 341 packages in 3.679s\n\n19 packages are looking for funding\n  run `npm fund` for details\n\nfound 0 vulnerabilities\n\n'
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/mobilenet)
# Result: b'+ @tensorflow-models/mobilenet@2.1.0\nadded 1 package and audited 342 packages in 6.331s\n\n19 packages are looking for funding\n  run `npm fund` for details\n\nfound 0 vulnerabilities\n\n'
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/handpose)
# Result: b'+ @tensorflow-models/handpose@0.0.7\nadded 1 package and audited 343 packages in 5.754s\n\n19 packages are looking for funding\n  run `npm fund` for details\n\nfound 0 vulnerabilities\n\n'
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/face-landmarks-detection)
# Result: b'+ @tensorflow-models/face-landmarks-detection@1.0.2\nadded 1 package and audited 344 packages in 5.59s\n\n19 packages are looking for funding\n  run `npm fund` for details\n\nfound 0 vulnerabilities\n\n'
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/face-landmarks-detection)
# Result: b'+ @tensorflow-models/face-landmarks-detection@1.0.2\nupdated 1 package and audited 344 packages in 1.982s\n\n19 packages are looking for funding\n  run `npm fund` for details\n\nfound 0 vulnerabilities\n\n'
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/face-embedding)
# Result: b''
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/knn-classifier)
# Result: b'+ @tensorflow-models/knn-classifier@1.2.4\nadded 1 package and audited 345 packages in 5.402s\n\n19 packages are looking for funding\n  run `npm fund` for details\n\nfound 0 vulnerabilities\n\n'
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/object-detection)
# Result: b''
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/pose-detection)
# Result: b'+ @tensorflow-models/pose-detection@2.1.0\nadded 2 packages from 1 contributor and audited 347 packages in 4.665s\n\n19 packages are looking for funding\n  run `npm fund` for details\n\nfound 0 vulnerabilities\n\n'
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/speech-commands)
# Result: b'+ @tensorflow-models/speech-commands@0.5.4\nadded 1 package and audited 349 packages in 6.381s\n\n19 packages are looking for funding\n  run `npm fund` for details\n\nfound 0 vulnerabilities\n\n'
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/universal-sentence-encoder)
# Result: b'+ @tensorflow-models/universal-sentence-encoder@1.3.3\nadded 1 package and audited 350 packages in 4.579s\n\n19 packages are looking for funding\n  run `npm fund` for details\n\nfound 0 vulnerabilities\n\n'
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/qna)
# Result: b'+ @tensorflow-models/qna@1.0.1\nadded 1 package and audited 351 packages in 5.04s\n\n19 packages are looking for funding\n  run `npm fund` for details\n\nfound 0 vulnerabilities\n\n'
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/transformer)
# Result: b''
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/gesture-estimation)
# Result: b''
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/human-pose-estimation)
# Result: b''
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/segmentation)
# Result: b''
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/visual-qa)
# Result: b''
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/visual-semantic-embedding)
# Result: b''
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/multihandpose)
# Result: b''
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/blazepose)
# Result: b''
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/efficientpose)
# Result: b''
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/facemesh)
# Result: b'+ @tensorflow-models/facemesh@0.0.5\nadded 2 packages and audited 353 packages in 7.733s\n\n19 packages are looking for funding\n  run `npm fund` for details\n\nfound 0 vulnerabilities\n\n'
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/deeplab)
# Result: b'+ @tensorflow-models/deeplab@0.2.1\nadded 1 package and audited 354 packages in 4.896s\n\n19 packages are looking for funding\n  run `npm fund` for details\n\nfound 0 vulnerabilities\n\n'
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/transformer-xl)
# Result: b''
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/attention-ocr)
# Result: b''
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/visual-qa)
# Result: b''
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/visual-semantic-embedding)
# Result: b''
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/multihandpose)
# Result: b''
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/blazepose)
# Result: b''
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/efficientpose)
# Result: b''
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/facemesh)
# Result: b'+ @tensorflow-models/facemesh@0.0.5\nupdated 1 package and audited 354 packages in 2.047s\n\n19 packages are looking for funding\n  run `npm fund` for details\n\nfound 0 vulnerabilities\n\n'
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/deeplab)
# Result: b'+ @tensorflow-models/deeplab@0.2.1\nupdated 1 package and audited 354 packages in 3.038s\n\n19 packages are looking for funding\n  run `npm fund` for details\n\nfound 0 vulnerabilities\n\n'
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/transformer-xl)
# Result: b''
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/attention-ocr)
# Result: b''
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/visual-qa)
# Result: b''
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/visual-semantic-embedding)
# Result: b''
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/multihandpose)
# Result: b''
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/blazepose)
# Result: b''
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/efficientpose)
# Result: b''
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/facemesh)
# Result: b'+ @tensorflow-models/facemesh@0.0.5\nupdated 1 package and audited 354 packages in 2.034s\n\n19 packages are looking for funding\n  run `npm fund` for details\n\nfound 0 vulnerabilities\n\n'
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/deeplab)
# Result: b'+ @tensorflow-models/deeplab@0.2.1\nupdated 1 package and audited 354 packages in 3.035s\n\n19 packages are looking for funding\n  run `npm fund` for details\n\nfound 0 vulnerabilities\n\n'
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/transformer-xl)
# Result: b''
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/attention-ocr)
# Result: b''
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/visual-qa)
# Result: b''
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/visual-semantic-embedding)
# Result: b''
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/multihandpose)
# Result: b''
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/blazepose)
# Result: b''
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/efficientpose)
# Result: b''
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/facemesh)
# Result: b'+ @tensorflow-models/facemesh@0.0.5\nupdated 1 package and audited 354 packages in 1.997s\n\n19 packages are looking for funding\n  run `npm fund` for details\n\nfound 0 vulnerabilities\n\n'
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/deeplab)
# Result: b'+ @tensorflow-models/deeplab@0.2.1\nupdated 1 package and audited 354 packages in 2.838s\n\n19 packages are looking for funding\n  run `npm fund` for details\n\nfound 0 vulnerabilities\n\n'
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/transformer-xl)
# Result: b''
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/attention-ocr)
# Result: b''
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/visual-qa)
# Result: b''
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/visual-semantic-embedding)
# Result: b''
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/multihandpose)
# Result: b''
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/blazepose)
# Result: b''
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/efficientpose)
# Result: b''
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/facemesh)
# Result: b'+ @tensorflow-models/facemesh@0.0.5\nupdated 1 package and audited 354 packages in 1.985s\n\n19 packages are looking for funding\n  run `npm fund` for details\n\nfound 0 vulnerabilities\n\n'
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/deeplab)
# Result: b'+ @tensorflow-models/deeplab@0.2.1\nupdated 1 package and audited 354 packages in 2.613s\n\n19 packages are looking for funding\n  run `npm fund` for details\n\nfound 0 vulnerabilities\n\n'
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/transformer-xl)
# Result: b''
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/attention-ocr)
# Result: b''
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/visual-qa)
# Result: b''
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/visual-semantic-embedding)
# Result: b''
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/multihandpose)
# Result: b''
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/blazepose)
# Result: b''
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/efficientpose)
# Result: b''
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/facemesh)
# Result: b'+ @tensorflow-models/facemesh@0.0.5\nupdated 1 package and audited 354 packages in 2.021s\n\n19 packages are looking for funding\n  run `npm fund` for details\n\nfound 0 vulnerabilities\n\n'
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/deeplab)
# Result: b'+ @tensorflow-models/deeplab@0.2.1\nupdated 1 package and audited 354 packages in 2.392s\n\n19 packages are looking for funding\n  run `npm fund` for details\n\nfound 0 vulnerabilities\n\n'
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/transformer-xl)
# Result: b''
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/attention-ocr)
# Result: b''
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/visual-qa)
# Result: b''
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/visual-semantic-embedding)
# Result: b''
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/multihandpose)
# Result: b''
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/blazepose)
# Result: b''
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/efficientpose)
# Result: b''
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/facemesh)
# Result: b'+ @tensorflow-models/facemesh@0.0.5\nupdated 1 package and audited 354 packages in 2.031s\n\n19 packages are looking for funding\n  run `npm fund` for details\n\nfound 0 vulnerabilities\n\n'
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/deeplab)
# Result: b'+ @tensorflow-models/deeplab@0.2.1\nupdated 1 package and audited 354 packages in 2.372s\n\n19 packages are looking for funding\n  run `npm fund` for details\n\nfound 0 vulnerabilities\n\n'
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/transformer-xl)
# Result: b''
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/attention-ocr)
# Result: b''
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/visual-qa)
# Result: b''
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/visual-semantic-embedding)
# Result: b''
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/multihandpose)
# Result: b''
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/blazepose)
# Result: b''
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/efficientpose)
# Result: b''
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/facemesh)
# Result: b'+ @tensorflow-models/facemesh@0.0.5\nupdated 1 package and audited 354 packages in 2.048s\n\n19 packages are looking for funding\n  run `npm fund` for details\n\nfound 0 vulnerabilities\n\n'
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/deeplab)
# Result: b'+ @tensorflow-models/deeplab@0.2.1\nupdated 1 package and audited 354 packages in 2.414s\n\n19 packages are looking for funding\n  run `npm fund` for details\n\nfound 0 vulnerabilities\n\n'
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/transformer-xl)
# Result: b''
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/attention-ocr)
# Result: b''
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/visual-qa)
# Result: b''
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/visual-semantic-embedding)
# Result: b''
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/multihandpose)
# Result: b''
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/blazepose)
# Result: b''
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/efficientpose)
# Result: b''
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/facemesh)
# Result: b'+ @tensorflow-models/facemesh@0.0.5\nupdated 1 package and audited 354 packages in 2.01s\n\n19 packages are looking for funding\n  run `npm fund` for details\n\nfound 0 vulnerabilities\n\n'
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/deeplab)
# Result: b'+ @tensorflow-models/deeplab@0.2.1\nupdated 1 package and audited 354 packages in 2.114s\n\n19 packages are looking for funding\n  run `npm fund` for details\n\nfound 0 vulnerabilities\n\n'
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/transformer-xl)
# Result: b''
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/attention-ocr)
# Result: b''
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/visual-qa)
# Result: b''
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/visual-semantic-embedding)
# Result: b''
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/multihandpose)
# Result: b''
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/blazepose)
# Result: b''
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/efficientpose)
# Result: b''
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/facemesh)
# Result: b'+ @tensorflow-models/facemesh@0.0.5\nupdated 1 package and audited 354 packages in 1.998s\n\n19 packages are looking for funding\n  run `npm fund` for details\n\nfound 0 vulnerabilities\n\n'
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/deeplab)
# Result: b'+ @tensorflow-models/deeplab@0.2.1\nupdated 1 package and audited 354 packages in 2.006s\n\n19 packages are looking for funding\n  run `npm fund` for details\n\nfound 0 vulnerabilities\n\n'
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/transformer-xl)
# Result: b''
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/attention-ocr)
# Result: b''
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/visual-qa)
# Result: b''
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/visual-semantic-embedding)
# Result: b''
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/multihandpose)
# Result: b''
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/blazepose)
# Result: b''
#
# Executing command: CommandExecutor(cd /path/to/TuringTown && npm install @tensorflow-models/efficientpose)
# Result: b''
#
# [('CommandExecutor', 'npm install phaser', b'+ phaser@3.60.0\nadded 2 packages from 2 contributors and audited 2 packages in 5.144s\nfound 0 vulnerabilities\n\n'), ('CommandExecutor', 'npm install socket.io', b'+ socket.io@4.6.1\nadded 21 packages from 69 contributors and audited 23 packages in 2.736s\nfound 0 vulnerabilities\n\n'), ('CommandExecutor', 'npm install express', b'+ express@4.18.2\nadded 58 packages from 39 contributors and audited 92 packages in 3.034s\n\n7 packages are looking for funding\n  run `npm fund` for details\n\nfound 0 vulnerabilities\n\n'), ('FileCreator', '/path/to/TuringTown', 'Directory /path/to/TuringTown created.'), ('CommandExecutor', 'cd /path/to/TuringTown && phaser init', b''), ('CommandExecutor', 'cd /path/to/TuringTown && npm init', b'This utility will walk you through creating a package.json file.\nIt only covers the most common items, and tries to guess sensible defaults.\n\nSee `npm help init` for definitive documentation on these fields\nand exactly what they do.\n\nUse `npm install <pkg>` afterwards to install a package and\nsave it as a dependency in the package.json file.\n\nPress ^C at any time to quit.\npackage name: (turingtown) '), ('CommandExecutor', 'cd /path/to/TuringTown && npm install', b'up to date in 0.292s\nfound 0 vulnerabilities\n\n'), ('CommandExecutor', 'cd /path/to/TuringTown && npm install nodemon', b'+ nodemon@2.0.22\nadded 32 packages from 28 contributors and audited 33 packages in 2.099s\n\n3 packages are looking for funding\n  run `npm fund` for details\n\nfound 0 vulnerabilities\n\n'), ('CommandExecutor', 'cd /path/to/TuringTown && npm install body-parser', b'+ body-parser@1.20.2\nadded 30 packages from 22 contributors and audited 82 packages in 1.644s\n\n9 packages are looking for funding\n  run `npm fund` for details\n\nfound 0 vulnerabilities\n\n'), ('CommandExecutor', 'cd /path/to/TuringTown && npm install cors', b'+ cors@2.8.5\nadded 3 packages from 3 contributors and audited 112 packages in 0.867s\n\n9 packages are looking for funding\n  run `npm fund` for details\n\nfound 0 vulnerabilities\n\n'), ('CommandExecutor', 'cd /path/to/TuringTown && npm install mongoose', b'+ mongoose@7.1.1\nadded 23 packages from 64 contributors and audited 137 packages in 3.355s\n\n10 packages are looking for funding\n  run `npm fund` for details\n\nfound 0 vulnerabilities\n\n'), ('CommandExecutor', 'cd /path/to/TuringTown && npm install dotenv', b'+ dotenv@16.0.3\nadded 1 package and audited 150 packages in 1.065s\n\n10 packages are looking for funding\n  run `npm fund` for details\n\nfound 0 vulnerabilities\n\n'), ('CommandExecutor', 'cd /path/to/TuringTown && npm install bcrypt', b'\n> bcrypt@5.1.0 install /path/to/TuringTown/node_modules/bcrypt\n> node-pre-gyp install --fallback-to-build\n\n[bcrypt] Success: "/path/to/TuringTown/node_modules/bcrypt/lib/binding/napi-v3/bcrypt_lib.node" is installed via remote\n+ bcrypt@5.1.0\nadded 55 packages from 134 contributors and audited 205 packages in 4.864s\n\n14 packages are looking for funding\n  run `npm fund` for details\n\nfound 0 vulnerabilities\n\n'), ('CommandExecutor', 'cd /path/to/TuringTown && npm install jsonwebtoken', b'+ jsonwebtoken@9.0.0\nadded 7 packages from 8 contributors and audited 257 packages in 2.043s\n\n14 packages are looking for funding\n  run `npm fund` for details\n\nfound 0 vulnerabilities\n\n'), ('CommandExecutor', 'cd /path/to/TuringTown && npm install axios', b'+ axios@1.4.0\nadded 7 packages from 21 contributors and audited 267 packages in 1.773s\n\n15 packages are looking for funding\n  run `npm fund` for details\n\nfound 0 vulnerabilities\n\n'), ('CommandExecutor', 'cd /path/to/TuringTown && npm install @tensorflow/tfjs', b'\n> core-js@3.29.1 postinstall /path/to/TuringTown/node_modules/core-js\n> node -e "try{require(\'./postinstall\')}catch(e){}"\n\n\x1bThank you for using core-js (\x1b https://github.com/zloirock/core-js \x1b) for polyfilling JavaScript standard library!\x1b\n\n\x1bThe projec ...
